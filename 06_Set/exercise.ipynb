# %% [markdown]
# # 문자열로 집합 생성
# safari_set = {"Bear", "Koara", "Gorilla", "Squirrel"}
#
# # 숫자 집합
# numbers = {1, 2, 3, 4, 5}
#
# # 혼합된 타입 집합
# mixed_set = {1, "Bear", (1, 2, 3)}

# %%
# 문자열로 집합 생성
safari_set = {"Bear", "Koara", "Gorilla", "Squirrel"}

# 숫자 집합
numbers = {1, 2, 3, 4, 5}

# 혼합된 타입 집합
mixed_set = {1, "Bear", (1, 2, 3)}

# %%
safari_set = set(["Monkey", "Tiger", "Wolf", 'Monkey'])
another_safari_Set = set(safari_set)
print(safari_set)
print(another_safari_Set)
# Out:
# {'Monkey', 'Tiger', 'Wolf'}
# {'Monkey', 'Tiger', 'Wolf'}

# %%
ohgiraffers = {'Pig', 'Squirrel', 'Bear', 'Gorilla'}
print(ohgiraffers)         # {'Bear', 'Squirrel', 'Gorilla', 'Pig'}
# print(ohgiraffers[0])    # Error 발생
# Out:
# {'Gorilla', 'Squirrel', 'Bear', 'Pig'}

# %%
ohgiraffers = {'Pig', 'Squirrel', 'Bear', 'Gorilla', 'Gorilla'}
print(ohgiraffers)
# Out:
# {'Gorilla', 'Squirrel', 'Bear', 'Pig'}

# %%
ohgiraffers = {'Pig', 'Squirrel', 'Bear', 'korilla'}

ohgiraffers.remove('Bear')  # set의 데이터 중 remove의 값 제거
ohgiraffers.add("cat")     # set에 add('값')으로 값을 추가
print(ohgiraffers)
# Out:
# {'korilla', 'Pig', 'Squirrel', 'cat'}

# %%
ohgiraffers = {1, "Squirrel", 2, 'Bear', 3.0, 'pig', tuple({'Gorilla'}), True}
print(ohgiraffers)    # {1, 2, 3.0, 'Squirrel', 'pig', 'Bear', ('Gorilla',)}
# Out:
# {1, 2, 3.0, ('Gorilla',), 'Squirrel', 'Bear', 'pig'}

# %%
javaTeam = {'Squirrel','Gorilla', 'Tiger', 'Sheep', 'monkey', 'wolf'}
print('Gorilla' in javaTeam)
# Out:
# True

# %%
ohgiraffers = set(["Monkey", "Tiger", "Wolf"])
print(ohgiraffers)    # {'Tiger', 'Monkey', 'Wolf'}

ohgiraffers.update(["Monkey", "Wolf", "Tiger", "Squirrel"])
print(ohgiraffers)    # {'Tiger', 'Squirrel', 'Monkey', 'Wolf'}
# Out:
# {'Monkey', 'Tiger', 'Wolf'}
# {'Monkey', 'Tiger', 'Squirrel', 'Wolf'}

# %%
ohgiraffers = {'Pig', 'Squirrel', 'Bear', 'Gorilla'}
# ohgiraffers.remove('Elephant')    # Error 발생
ohgiraffers.remove('Squirrel') # 함수안에 들어가는 이걸 "매개변수 or 인자 or 옵션?"
print(ohgiraffers)    #  {'Bear', 'Squirrel', 'Gorilla'}
# Out:
# {'Gorilla', 'Bear', 'Pig'}

# %%
ohgiraffers = {'Pig', 'Squirrel', 'Bear', 'Gorilla'}


ohgiraffers.discard("Elephant")
print(ohgiraffers)
# Out:
# {'Gorilla', 'Squirrel', 'Bear', 'Pig'}

# %%
ohgiraffers = {'Pig', 'Squirrel', 'Bear', 'Gorilla'}

ohgiraffers.pop()
print(ohgiraffers)
# Out:
# {'Squirrel', 'Bear', 'Pig'}

# %%
ohgiraffers.clear()
print(ohgiraffers)
# Out:
# set()

# %%
javaTeam = {'Squirrel','Gorilla', 'Tiger', 'Sheep', 'monkey', 'wolf'}
pythonTeam = {'Pig', 'Squirrel', 'Bear', 'Gorilla'}

ohgiraffers = javaTeam.union(pythonTeam)
                             # {'wolf', 'Sheep', 'Tiger', 'Gorilla', 'monkey', 'Squirrel', 'Pig', 'Bear'}
print(ohgiraffers)              # {'wolf', 'Sheep', 'Tiger', 'Gorilla', 'monkey', 'Squirrel', 'Pig', 'Bear'}
# Out:
# {'Sheep', 'wolf', 'Gorilla', 'Pig', 'Squirrel', 'Bear', 'Tiger', 'monkey'}

# %%
new_ohgiraffers = javaTeam | pythonTeam #or조건과 비슷하다.
print(new_ohgiraffers)
# Out:
# {'Sheep', 'wolf', 'Gorilla', 'Pig', 'Squirrel', 'Bear', 'Tiger', 'monkey'}

# %%
print(javaTeam.intersection(pythonTeam))
print(javaTeam & pythonTeam) #and 조건과 비슷하다.
# Out:
# {'Gorilla', 'Squirrel'}
# {'Gorilla', 'Squirrel'}

# %%
print(javaTeam.difference(pythonTeam))
print(javaTeam - pythonTeam)
# Out:
# {'Tiger', 'Sheep', 'monkey', 'wolf'}
# {'Tiger', 'Sheep', 'monkey', 'wolf'}

# %%
print(javaTeam.symmetric_difference(pythonTeam)) 
print(javaTeam ^ pythonTeam)  #NOT 조건과 비슷하다.
# Out:
# {'Sheep', 'Pig', 'wolf', 'Bear', 'Tiger', 'monkey'}
# {'Sheep', 'Pig', 'wolf', 'Bear', 'Tiger', 'monkey'}

# %%
ohgiraffers = {'Squirrel','Gorilla', 'Tiger', 'Sheep', 'monkey', 'wolf'}
zzap_ohgiraffers = ohgiraffers.copy()

print(ohgiraffers)
print(zzap_ohgiraffers)
# Out:
# {'Tiger', 'Sheep', 'wolf', 'Gorilla', 'Squirrel', 'monkey'}
# {'Tiger', 'Sheep', 'wolf', 'Gorilla', 'Squirrel', 'monkey'}

# %%
zzap_ohgiraffers.remove('Tiger')

print(ohgiraffers)
print(zzap_ohgiraffers)
# Out:
# {'Tiger', 'Sheep', 'wolf', 'Gorilla', 'Squirrel', 'monkey'}
# {'Sheep', 'wolf', 'Gorilla', 'Squirrel', 'monkey'}

# %% [markdown]
# ### . 딕셔너리란
#
# <aside>
# 💡 키(key)와 값(value)의 쌍으로 구성된 자료형(데이터 구조)로, 키를 통해 값을 찾을 수 있으므로 매우 빠른 조회 성능을 보여준다. 연관 배열(associative array) 또는 해시(hash)라고도 한다.
#
# </aside>

# %%
teacher = {'name': 'bear', 'team': 'ohgiraffers'}
print(type(teacher))    # <class 'dict'>

# key 값을 활용한 value 탐색
print(teacher['name'])    # bear
print(teacher['team'])    # ohgiraffers
# Out:
# <class 'dict'>
# bear
# ohgiraffers

# %%
ohgiraffers = {
    'tiger' : 'langChain', 
    'Squirrel' :'JPA', 
    'Bear':'Python', 
    'Gorilla':'Spring'
}
print(ohgiraffers)    # {'tiger': 'langChain', 'Squirrel': 'JPA', 'Bear': 'Python', 'Gorilla': 'Spring'}

print(ohgiraffers['tiger'])       # langChain
print(ohgiraffers['Squirrel'])    # JPA
# Out:
# {'tiger': 'langChain', 'Squirrel': 'JPA', 'Bear': 'Python', 'Gorilla': 'Spring'}
# langChain
# JPA

# %%
ohgiraffers = {
    'tiger':'langChain', 
    'Squirrel':'JPA', 
    'Bear':'Python', 
    'Gorilla':'Spring', 
    "Squirrel":"MyBatis"
}
print(ohgiraffers['Squirrel'])    # MyBatis
print(ohgiraffers)
# invalid_key_teacher = {["name", "team"] : 'bear.ohgiraffer'}  # Error 발생
# Out:
# MyBatis
# {'tiger': 'langChain', 'Squirrel': 'MyBatis', 'Bear': 'Python', 'Gorilla': 'Spring'}

# %%
valid_key_dic = {("name", "team") : 'bear.ohgriaffers'}
print(valid_key_dic[("name", "team")])    # bear.ohgriaffers
# Out:
# bear.ohgriaffers

# %%
ohgiraffers = {
    'tiger' : 'langchain',
    'squirrel' : 'JAP',
    'Bear' : 'python',
    'Gorilla' : 'Spring'
}

print(ohgiraffers['Bear'])
print(ohgiraffers['Gorilla'])
# Out:
# python
# Spring

# %%
ohgiraffers = {
    'tiger' : 'langChain', 
    'Squirrel' :'JPA', 
    'Bear':'Python', 
    'Gorilla':'Spring'
}
print('tiger' in ohgiraffers)    # True

# %%
ohgiraffers = {
    'tiger' : 'langChain',
    'Squirrel' :'JPA',
    'Bear':'Python',
    'Gorilla':'Spring'
}

print(ohgiraffers['tiger'])         # langChain
print(ohgiraffers.get('tiger'))     # langChain
print(ohgiraffers.get('test'))

# %%
ohgiraffers = {
    'tiger' : 'langChain',
    'Squirrel' :'JPA',
    'Bear':'Python',
    'Gorilla':'Spring'
}

print(ohgiraffers.keys())
# Out:
# dict_keys(['tiger', 'Squirrel', 'Bear', 'Gorilla'])

# %%
ohgiraffers = {
    'tiger' : 'langChain',
    'Squirrel' :'JPA',
    'Bear':'Python',
    'Gorilla':'Spring'
}

print(ohgiraffers.values())    # dict_values(['langChain', 'JPA', 'Python', 'Spring'])
# Out:
# dict_values(['langChain', 'JPA', 'Python', 'Spring'])

# %%
ohgiraffers = {
    'tiger' : 'langChain',
    'Squirrel' :'JPA',
    'Bear':'Python',
    'Gorilla':'Spring'
}

print(ohgiraffers.items())    # dict_items([('tiger', 'langChain'), ('Squirrel', 'JPA'), ('Bear', 'Python'), ('Gorilla', 'Spring')])
# Out:
# dict_items([('tiger', 'langChain'), ('Squirrel', 'JPA'), ('Bear', 'Python'), ('Gorilla', 'Spring')])

# %%
ohgiraffers = {
    'tiger' : 'langChain',
    'Squirrel' :'JPA',
    'Bear':'Python',
    'Gorilla':'Spring'
}

print(ohgiraffers.pop('tiger'))    # langChain
# print(ohgiraffers.pop('test'))   # Error 발생
print(ohgiraffers)                 # {'Squirrel': 'JPA', 'Bear': 'Python', 'Gorilla': 'Spring'}

# %%
del ohgiraffers['Squirrel']
print(ohgiraffers)
# Out:
# {'tiger': 'langChain', 'Bear': 'Python', 'Gorilla': 'Spring'}

# %%
ohgiraffers = {
    'tiger' : 'langChain',
    'Squirrel' :'JPA',
    'Bear':'Python',
    'Gorilla':'Spring'
}

poped_item = ohgiraffers.popitem()

print(poped_item)          # ('Gorilla', 'Spring')
print(type(poped_item))    # <class 'tuple'>
print(ohgiraffers)
# Out:
# ('Gorilla', 'Spring')
# <class 'tuple'>
# {'tiger': 'langChain', 'Squirrel': 'JPA', 'Bear': 'Python'}

# %%
ohgiraffers = {
    'tiger' : 'langChain',
    'Squirrel' :'JPA',
    'Bear':'Python',
    'Gorilla':'Spring'
}

ohgiraffers.update({'animal' :'Squirrel'})  
print(ohgiraffers)  # {'tiger': 'langChain', 'Squirrel': 'JPA', 'Bear': 'Python', 'Gorilla': 'Spring', 'test': 'value'}
# Out:
# {'tiger': 'langChain', 'Squirrel': 'JPA', 'Bear': 'Python', 'Gorilla': 'Spring', 'animal': 'Squirrel'}

# %%
ohgiraffers = {
    'tiger' : 'langChain',
    'Squirrel' :'JPA',
    'Bear':'Python',
    'Gorilla':'Spring'
}

ohgiraffers.clear()
print(ohgiraffers)
# Out:
# {}

# %%
k = ['one', 'two', 'three']
v = [1,2,3]

# 두개의 자료를 순서대로 쌍으로 묶은 zip객체를 반환
t = zip(k,v)
print(t) #<zip object at 0x034ABE90>
print(type(t))
# Out:
# <zip object at 0x0000025C73D5EA00>
# <class 'zip'>

# %%
# 1.shallow copy
a = {'a': 1, 'b': 2, 'c': 3}
b = a # 사전 레퍼런스의 복사 (공유됨)
print(a)
print(b)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# {'a': 1, 'b': 2, 'c': 3}

# %%
a['a'] = 100
print(a)
print(b)
# Out:
# {'a': 100, 'b': 2, 'c': 3}
# {'a': 100, 'b': 2, 'c': 3}

# %%
# 2.deep copy
c = {'a': 1, 'b': 2, 'c': 3}
d = c.copy()
print(c)
print(d)

c['a'] = 300
print(c)
print(d) # 변경되지 않음.
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# {'a': 1, 'b': 2, 'c': 3}
# {'a': 300, 'b': 2, 'c': 3}
# {'a': 1, 'b': 2, 'c': 3}

# %%
a = {'a': [1,2,3], 'b':100}
b = a.copy()
print(a) #{'a': [1, 2, 3], 'b': 100}
print(b) #{'a': [1, 2, 3], 'b': 100}

a['b'] = 200
a['a'][0] = 999
print(a) #{'a': [999, 2, 3], 'b': 200}
print(b) #{'a': [999, 2, 3], 'b': 100}
# Out:
# {'a': [1, 2, 3], 'b': 100}
# {'a': [1, 2, 3], 'b': 100}
# {'a': [999, 2, 3], 'b': 200}
# {'a': [999, 2, 3], 'b': 100}

# %%
a = {'user':{'name':'김동현','age':20},'amount':123}
b = a.copy()
print(a)
print(b)

a['user']['name'] = '김동팔'
print(a)
print(b)
# Out:
# {'user': {'name': '김동현', 'age': 20}, 'amount': 123}
# {'user': {'name': '김동현', 'age': 20}, 'amount': 123}
# {'user': {'name': '김동팔', 'age': 20}, 'amount': 123}
# {'user': {'name': '김동팔', 'age': 20}, 'amount': 123}

# %%
dic1 = {'a':10, 'b':20}
dic2 = {'c':100, 'd':300}
dic1.update(dic2)

print(dic1) #{'a': 10, 'b': 20, 'c': 100, 'd': 300}
print(dic2) #{'c': 100, 'd': 300}
# Out:
# {'a': 10, 'b': 20, 'c': 100, 'd': 300}
# {'c': 100, 'd': 300}

# %%
numbers = {'first': 1, 'second': 2, 'third': 3, 'Fourth': 4}
numbers['hundred'] = 100
numbers['fifth'] = 5

print(list(numbers)) #['first', 'second', 'third', 'Fourth', 'hundred', 'fifth']

# key값 정렬
print(sorted(numbers)) #['Fourth', 'fifth', 'first', 'hundred', 'second', 'third']

# value값 정렬
print(sorted(numbers.values())) #[1, 2, 3, 4, 5, 100]

# key정렬 (value값 정렬에 따라)
print(sorted(numbers, key=numbers.__getitem__))
# Out:
# ['first', 'second', 'third', 'Fourth', 'hundred', 'fifth']
# ['Fourth', 'fifth', 'first', 'hundred', 'second', 'third']
# [1, 2, 3, 4, 5, 100]
# ['first', 'second', 'third', 'Fourth', 'fifth', 'hundred']

# %% [markdown]
# 1. `fruits`라는 셋을 선언하고 `'apple', 'banana', 'cherry'`를 추가하세요.
#
# 1. `print()`를 사용하여 `fruits`를 출력하세요.

# %%
fruits_set = {'apple', 'banana', 'cherry'}
print(type(fruits_set))
print(fruits)
# Out:
# <class 'set'>
# {'banana', 'apple', 'cherry'}

# %% [markdown]
# 아래 조건에 따라 셋의 **특정 요소를 제거**하고 결과를 출력하세요.
#
# 1. `animals`라는 셋에 `'cat', 'dog', 'bird', 'fish'`를 저장하세요.
# 2. `'bird'`를 제거한 후, `print()`를 사용해 남은 요소를 출력하세요.

# %%
animals_set = {'cat', 'dog', 'bird', 'fish'}
animals_set.remove('bird')

print(animals_set)
# Out:
# {'fish', 'cat', 'dog'}

# %% [markdown]
# 다음 조건에 맞게 **집합 연산**을 수행하세요.
#
# 1. `set1`에 `{1, 2, 3}`을 저장하고, `set2`에 `{3, 4, 5}`를 저장하세요.
# 2. `set1`과 `set2`의 **합집합**을 구해서 출력하세요.

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}

result = (set1 | set2)
print(result)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 아래 조건을 만족하는 딕셔너리를 생성하세요.
#
# 1. `student`라는 이름의 딕셔너리를 선언하고 다음 키-값 쌍을 추가하세요:
#     - `'name'`: `'John'`
#     - `'age'`: `20`
#     - `'major'`: `'Computer Science'`
# 2. `'age'`의 값을 출력하세요.

# %%
student = {
  'name': ' John',
  'age' : '20' ,
  'major' : 'Computer Science'
}

print(student['age'])
# Out:
# 20

# %% [markdown]
# 아래 조건에 맞게 딕셔너리를 수정하세요.
#
# 1. `scores`라는 딕셔너리에 `'math': 80, 'english': 90`을 저장하세요.
# 2. `'math'`의 값을 `95`로 변경하고 딕셔너리를 출력하세요.

# %%
scores = {
    'math' : 80,
    'english' : 90,
}

scores.update({'math' : '95'})
print(scores)
# Out:
# {'math': '95', 'english': 90}

# %% [markdown]
# 다음 조건에 맞게 **셋의 메서드**를 활용하세요.
#
# 1. `colors1`에 `'red', 'blue', 'green'`을 저장하세요.
#
#     ---
#
#
# 1. `colors2`에 `'blue', 'yellow', 'pink'`를 저장하세요.
# 2. 두 셋의 **교집합**을 구하여 출력하세요.

# %%
colors1 = {'red', 'blue', 'green'}
colors2 = {'blue', 'yellow', 'pink'}

print(colors1 & colors2)
# Out:
# {'blue'}

# %% [markdown]
# 다음 조건에 맞는 **딕셔너리 메서드**를 사용하세요.
#
# 1. `'name': 'Alice', 'age': 25, 'city': 'Seoul'`
# 2. 메서드를 사용해 딕셔너리의 모든 키를 출력하세요.
# 3. 메서드를 사용해 딕셔너리의 모든 값을 출력하세요.

# %%
info = {
    'name' : 'Alice',
    'age' : 25,
    'city' : 'Seoul',
}

print(info.keys())
print(info.values())
print(info.items())
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['Alice', 25, 'Seoul'])
# dict_items([('name', 'Alice'), ('age', 25), ('city', 'Seoul')])

# %% [markdown]
# 다음 조건에 맞게 딕셔너리를 조작하세요.
#
# 1. `students` 딕셔너리에 `'student1': 85, 'student2': 90, 'student3': 95`를 저장하세요.
# 2. `pop()` 메서드를 사용해 `'student2'`의 값을 제거하고, 제거된 값을 출력하세요.

# %%
students = {
    'student1': 85, 
    'student2': 90,
    'student3': 95,
}

print(students.pop('student2'))
print(students)
# Out:
# 90
# {'student1': 85, 'student3': 95}

# %% [markdown]
# 아래 조건에 맞는 **셋과 딕셔너리**를 사용하세요.
#
# 1. `numbers`라는 셋에 `{1, 2, 3, 4, 5}`를 저장하세요.
# 2. 딕셔너리 `squares`를 생성하고, 각 숫자를 키로, 숫자의 **제곱값**을 값으로 저장하세요.
# 3. 딕셔너리를 출력하세요.

# %% [markdown]
# ### **문제 10**
#
# 다음 조건에 맞는 프로그램을 작성하세요.
#
# 1. 두 셋 `A = {1, 2, 3, 4}`와 `B = {3, 4, 5, 6}`가 있습니다.
# 2. `A`와 `B`의 **대칭 차집합**을 구하세요.
# 3. 결과를 `print()`를 사용해 출력하세요.
