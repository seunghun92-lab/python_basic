# %% [markdown]
# ### **문제 1: `.txt` 파일 생성 및 쓰기**
#
# 다람쥐는 하루 동안 배운 내용을 기록하기 위해 일기를 작성합니다. 다음 작업을 수행하세요.
#
# 1. `diary.txt` 파일을 생성하고, 다람쥐가 오늘 배운 내용을 작성하세요.
# 2. 내용:
#
#     ```
#     오늘은 파일 입출력을 배웠습니다.
#     다양한 파일 확장자와 접근 모드를 사용할 수 있다는 점이 흥미로웠습니다.
#     ```
#
# 3. 파일을 닫고 다시 열어 작성된 내용을 출력하세요.

# %%
with open('diary.txt', 'w', encoding='utf-8') as f:
    f.write("오늘은 파일 입출력을 배웠습니다.\n다양한 파일 확장자와 접근 모드를 사용할 수 있다는 점이 흥미로웠습니다.")

with open('diary.txt', 'r', encoding='utf-8') as f2:
    print(f2.read())
# Out:
# 오늘은 파일 입출력을 배웠습니다.
# 다양한 파일 확장자와 접근 모드를 사용할 수 있다는 점이 흥미로웠습니다.

# %% [markdown]
# ### **`.csv` 파일 생성 및 읽기**
#
# 다람쥐는 이직 준비를 위해 지원했던 회사들의 정보를 저장하려고 합니다.
#
# 1. `applications.csv` 파일을 생성하고 다음 데이터를 작성하세요.
#
#     ```
#     회사명,직무,결과
#     회사A,데이터 분석가,합격
#     회사B,소프트웨어 엔지니어,불합격
#     회사C,제품 관리자,진행 중
#     ```
#
# 2. 파일을 닫고 다시 열어 모든 데이터를 출력하세요.

# %%
with open("applications.csv", 'w', encoding='utf-8') as f:
    f.write("""회사명, 직무, 결과\n"
    "회사A,데이터 분석가,합격\n"
    "회사B,소프트웨어 엔지니어,불합격\n"
    "회사C,제품 관리자,진행 중\n"
""")
f.close()

with open("application.csv", 'r', encoding="utf-8") as f2:
    reader = f2.readline()
    for row in reader:
        print(row)
# Out:
# 회
# 사
# 명
# ,
# 직
# 무
# ,
# 결
# 과

# %%
# CSV 형태로 저장하기
import csv

data = [
    ["회사명", "직무", "결과"],
    ["회사A,데이터 분석가,합격"],
    ["회사B,소프트웨어 엔지니어,불합격"],
    ["회사C,제품 관리자,진행 중"]
]
#파일 쓰기
with open("application.csv", "w", newline="", encoding="utf=8") as f:
    csv_writer = csv.writer(f) #csv 작성 도구 생성
    csv_writer.writerows(data)
#파일 읽기
with open("application.csv", 'r', encoding="utf-8") as f:
    for row in reader: #csv.reader(파일객체)
        print(", ". join(row)) #리스트를 문자열로 변환하여 출력
# Out:
# <>:5: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\신승훈\AppData\Local\Temp\ipykernel_25112\2339520910.py:5: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   ["회사명", "직무", "결과"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 # CSV 형태로 저장하기
#       2 import csv
#       4 data = [
# ----> 5     ["회사명", "직무", "결과"]
#       6     ["회사A,데이터 분석가,합격"]
#       7     ["회사B,소프트웨어 엔지니어,불합격"]
#       8     ["회사C,제품 관리자,진행 중"]
#       9 ]
#      10 #파일 쓰기
#      11 with open("application.csv", "w", newline="", encoding="utf=8") as f:
#
# TypeError: list indices must be integers or slices, not str

# %%
import csv 

data = [
    {"회사명": "회사A", "직무" : "데이터분석가", "결과" : "합격"},
    {"회사명": "회사B", "직무" : "소프트웨어 엔지니어", "결과" : "합격"},
    {"회사명": "회사C", "직무" : "제품 관리자", "결과" : "합격"},
]

with open("appli`cation.csv", "w", newline="", encoding="utf=8") as f:
    fieldnames = ["회사명", "직무", "결과"]
    writer = csv.writer(f, fieldnames) #csv 작성 도구 생성
    writer.writeheader()
    writer.writerows(data)

with open("application.csv", 'r', encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader: #csv.reader(파일객체)
        print(", ". join(row))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 12
#      10     fieldnames = ["회사명", "직무", "결과"]
#      11     writer = csv.writer(f, fieldnames) #csv 작성 도구 생성
# ---> 12     writer.writeheader()
#      13     writer.writerows(data)
#      15 with open("application.csv", 'r', encoding="utf-8") as f:
#
# AttributeError: '_csv.writer' object has no attribute 'writeheader'

# %% [markdown]
# ### **문제 3: `.log` 파일 읽기**
#
# 다람쥐는 프로그램 실행 로그를 확인하려고 합니다.
#
# 1. `system.log` 파일을 다음 내용으로 생성하세요.
#
#     ```
#     [INFO] 2024-01-01 12:00:00: 시스템 시작
#     [WARN] 2024-01-01 12:05:00: 메모리 사용량 증가
#     [ERROR] 2024-01-01 12:10:00: 프로그램 종료
#     ```
#
# 2. 파일을 읽어와 `WARN` 또는 `ERROR`가 포함된 줄만 출력하세요.

# %%
# 로그 파일 쓰기
with open('system.log', 'w', encoding="utf-8") as f:
    log_content = [
        "[INFO] 2024-01-01 12:00:00: 시스템 시작\n"
        "[WARN] 2024-01-01 12:05:00: 메모리 사용량 증가\n"
        "[ERROR] 2024-01-01 12:10:00: 프로그램 종료\n"
    ]
    f.writelines(log_content)
with open('system.log', 'r', encoding="utf-8") as f:
    for line in f:
        if 'WARN' in line or "ERROR" in line:
            print(line)
# Out:
# [WARN] 2024-01-01 12:05:00: 메모리 사용량 증가
#
# [ERROR] 2024-01-01 12:10:00: 프로그램 종료

# %% [markdown]
# ### **: `.json` 파일 생성 및 읽기**
#
# 다람쥐는 좋아하는 음식 데이터를 저장하고 싶습니다.
#
# 1. `favorite_foods.json` 파일을 생성하고 다음 데이터를 작성하세요.
#
#     ```json
#     {
#         "name": "다람쥐",
#         "favorite_foods": ["도토리", "호두", "밤"]
#     }
#     ```
#
# 2. 파일을 읽어와 다람쥐의 좋아하는 음식 리스트를 출력하세요.

# %%
with open('favorite_foods.json', 'w', encoding="utf_8") as json_file:
    json_file.write('{"name" : "카피바라", "favorite_foods" : ["고기", "과자", "아이스크림"])

with open('favorite_food.json', 'r', encoding="utf-8") as json_file:
    json_text = json_file.read()
    print(json_text.split("[")[1].split("]")[0])
# Out:
#   Cell In[37], line 2
#     json_file.write({"name", "카피바라", "facorite_foods"} : ["고기, 과자", "아이스크림"])
#                                                        ^
# SyntaxError: invalid syntax

# %%
import json

data = '{"name": "카피바라","favorite_foods": ["고기", "과자", "아이스크림"]}'

with open('favortie_foods.json', 'w', encoding='utf-8') as json_file:
    json_file.write(data)

with open('favortie_foods.json', 'r', encoding='utf-8') as json_file2:
    json_dict = json.load(json_file2)
    print(json_dict)
    print(json_dict['favorite_foods'])
# Out:
# {'name': '카피바라', 'favorite_foods': ['고기', '과자', '아이스크림']}
# ['고기', '과자', '아이스크림']

# %% [markdown]
# ### **문제 5: `.html` 파일 수정**
#
# 다람쥐는 자신의 이력서를 작성 중입니다. `resume.html` 파일을 다음 내용으로 생성하고 수정하세요.
#
# 1. `resume.html` 파일 생성 내용:
#
#     ```html
#     <html>
#         <head><title>다람쥐의 이력서</title></head>
#         <body>
#             <h1>다람쥐의 이력서</h1>
#             <p>경력: 신입</p>
#         </body>
#     </html>
#     ```
#
# 2. 수정 작업:
#     - `<p>` 태그 안의 "신입"을 "1년 경력"으로 변경하세요.
# 3. 수정된 파일을 읽어와 전체 내용을 출력하세요.

# %%
with open ('resume.html', 'w', encoding="utf-8") as f:
    f.write("""
        <html>
            <head>
                <title>다람쥐의 이력서</title>
            </head>
            <body>
                <h1>다람쥐의 이력서</h1>
                <p>경력: 신입</p>
        </body>
    </html>
    """)

# %%
with open("resume.html", 'r', encoding="utf-8") as f:
    contents = f.read()

print(contents)

# %%
        <html>
            <head>
                <title>다람쥐의 이력서</title>
            </head>
            <body>
                <h1>다람쥐의 이력서</h1>
                <p>경력: 신입</p>
        </body>
    </html>

# %%
modified_contents = contents.replace('신입', '1년')

with open('resume.html', 'w', encoding="utf-8") as f:
    f.write(modified_contents)

    with open('resume.html', 'w', encoding="utf-8") as f:
    print(f.read())
