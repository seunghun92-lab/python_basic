# %%
f = open('.\\dev\\frog_song.txt', 'r', encoding="utf-8")
f.read()
# f.close()
# Out:
# '나크체므쳄ㅊ느첸'

# %%
import os

os.makedirs(C:/PYTHON/python_basic/17_file/dev, exist_ok=True)

# %%
f = open('./dev/frog_song_txt', 'w', encoding='utf-8')

# %%
f.write('개구리 소년 빰빠바 개구리 소년 빰빠바\n\n네가 울면 무지개 연못에 비가 온단다\n비바람 몰아쳐도 이겨내고\n일곱번 넘어져도 일어나~라\n울지말고 일어나 피리를 불어라\n\n삘릴리 개굴개굴 삘릴리리\n삘릴리 개굴개굴 삘릴리리\n\n무지개 연못에 웃음꽃 핀다.\n')
f.close()

# %%
f.close()

# %%
f = open('.\\dev\\frog_song_txt', 'w', encoding="utf-8")
f.write('개구리 소년 빰빠바 개구리 소년 빰빠바\n\n네가 울면 무지개 연못에 비가 온단다\n비바람 몰아쳐도 이겨내고\n일곱번 넘어져도 일어나~라\n울지말고 일어나 피리를 불어라\n\n삘릴리 개굴개굴 삘릴리리\n삘릴리 개굴개굴 삘릴리리\n\n무지개 연못에 웃음꽃 핀다.\n')
f.close()

# %%
f = open('.\\dev\\frog_song_txt', 'r', encoding='utf-8')

#f = open('python_basic/17_file/exercise.ipynb', 'r')
    
data = f.read()
print(data)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('.\\dev\\frog_song_txt', 'w', encoding="utf-8")
data = ['개구리 소년 빰빠바 개구리 소년 빰빠바\n\n', '네가 울면 무지개 연못에 비가 온단다\n', '비바람 몰아쳐도 이겨내고\n', '일곱번 넘어져도 일어나~라\n', '울지말고 일어나 피리를 불어라\n\n', '삘릴리 개굴개굴 삘릴리리\n', '삘릴리 개굴개굴 삘릴리리\n\n', '무지개 연못에 웃음꽃 핀다.\n']
f.write
# Out:
# <function TextIOWrapper.write(text, /)>

# %%
f = open('dev/frog_song_txt', 'r', encoding='utf-8')

line = f.readline()
print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바

# %%
f = open('dev/frog_song_txt', 'r', encoding='utf-8')

while True:
    line = f.readline()

    if not line:
        break

    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('dev/frog_song_txt', 'r', encoding='utf-8')

line = f.readline()
print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바

# %%
f = open('dev/frog_song_txt', 'r', encoding='utf-8')

lines = f.readlines()
for line in lines:
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('dev/frog_song_txt', 'r', encoding='utf-8')

for line in f:
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f1 = open('dev/frog_song_txt', 'a', encoding='utf-8')
f1.write("노래 끝!")
f1.close()

f2 = open('dev/frog_song_txt', 'r', encoding='utf-8')
print(f2.read())
f2.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.
# 노래 끝!

# %%
f1 = open('dev/frog_song_txt', 'a', encoding='utf-8')
f1.write(str(10))
f1.close()

f2 = open('dev/frog_song_txt', 'r', encoding='utf-8')
print(f2.read())
f2.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.
# 노래 끝!1010

# %%
f.close()

# %%
#절대 경로
#with open("C:/PYTHON/python_basic/17_file/new/fi/le/frog_song.txt", 'w', encoding='utf-8') as f:
    #f.write("Life is too short, you need python")

#상대 경로
with open("./new/fi/le/frog_song.txt", "w", encoding='utf-8') as f:
    f.write("Life is too short, you need python2")
