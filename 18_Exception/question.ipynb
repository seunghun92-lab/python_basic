# %% [markdown]
# ### **문제 1: 모든 예외 처리**
#
# 다람쥐는 파일에서 데이터를 읽으려고 하지만, 파일이 없을 경우 프로그램이 중단되지 않도록 처리하고 싶습니다.
#
# 1. `data.txt` 파일을 읽으려고 시도하세요.
# 2. 파일이 없을 경우, `"파일이 존재하지 않습니다."`를 출력하세요.
# 3. 파일이 존재하면 파일 내용을 출력하세요.:

# %%
try:
    with open("data.txt", "r" , encoding="utf-8") as file_read:
        content = file_read.read()
except:
    print("파일이 존재하지 않습니다.")
else:
    print(content)
# Out:
# 파일이 존재하지 않습니다.

# %%
with open("data.txt", "r" , encoding="utf-8") as f:
    
    content = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 with open("data.txt", "r" , encoding="utf-8") as f:
#       3     content = f.read()
#
# File c:\PYTHON\python_venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %% [markdown]
# 다람쥐는 사용자에게 나이를 입력받아 성인인지 확인하려고 합니다.
#
# 1. 사용자로부터 나이를 입력받아 정수로 변환하세요.
# 2. 입력값이 숫자가 아닐 경우, `"숫자를 입력해야 합니다."`를 출력하세요.
# 3. 숫자가 올바르게 입력되면 나이가 19 이상인지 확인하고, 19 이상이면 `"성인입니다."`, 그렇지 않으면 `"미성년자입니다."`를 출력하세요.

# %%
try:
    age=int(input('나이를 입력하세요'))

    if age >= 19:
        print("성인입니다.")
    else:
        print("미성년자입니다.")

except:
    print("에러 발생")
# Out:
# 에러 발생

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 age=int(input('나이를 입력하세요'))
#       3 if age >= 19:
#       4     print("성인입니다.")
#
# ValueError: invalid literal for int() with base 10: 'asd'

# %% [markdown]
# ### **특수 예외 상황과 오류 변수 사용**
#
# 다람쥐는 숫자 두 개를 입력받아 나누기를 수행하려고 합니다.
#
# 1. 사용자로부터 두 숫자를 입력받아 나누기를 수행하세요.
# 2. 첫 번째 숫자가 0으로 나누기를 시도하면 `"0으로 나눌 수 없습니다."`를 출력하세요.
# 3. 입력값이 숫자가 아니면 `"숫자를 입력해야 합니다."`를 출력하세요.
# 4. 오류 메시지를 출력할 때 발생한 오류 내용을 함께 출력하세요.

# %%
try:
    num1 = int(input("두 숫자를 입력하세요."))
    num2 = int(input("두 숫자를 입력하세요."))
    num1 / num2
except ZeroDivisionError as e:
    print("0으로 나눌 수 없습니다.", e)
except ValueError as e:
    print("숫자를 입력해야 합니다.", e)
# Out:
# 숫자를 입력해야 합니다. invalid literal for int() with base 10: 'af'

# %%
num1 = int(input("두 숫자를 입력하세요."))
num2 = int(input("두 숫자를 입력하세요."))
num1 / num2
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 num1 = int(input("두 숫자를 입력하세요."))
#       2 num2 = int(input("두 숫자를 입력하세요."))
# ----> 3 num1 / num2
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### **문제 4: finally 블럭**
#
# 다람쥐는 프로그램 실행 후 파일 자원을 반드시 정리해야 합니다.
#
# 1. `log.txt` 파일을 읽으려고 시도하세요.
# 2. 파일을 여는 중 예외가 발생할 경우, `"파일을 열 수 없습니다."`를 출력하세요.
# 3. 예외 발생 여부와 상관없이 파일 자원을 정리하는 메시지 `"파일 자원 정리 완료"`를 출력하세요.

# %%
try:
    with open('log.txt', 'r', encoding='utf-8') as f:
        print(f.read())
except:
    print("파일을 열 수 없습니다.")
finally:
    print("파일 자원 정리 완료")
# Out:
# 파일을 열 수 없습니다.
# 파일 자원 정리 완료

# %% [markdown]
# ### **문제 5: try-else 블럭**
#
# 다람쥐는 사용자로부터 숫자를 입력받아 2로 나눈 결과를 출력하려고 합니다.
#
# 1. 사용자로부터 숫자를 입력받아 정수로 변환하세요.
# 2. 입력값이 숫자가 아닐 경우 `"숫자를 입력해야 합니다."`를 출력하세요.
# 3. 숫자가 올바르게 입력되면 입력값을 2로 나눈 결과를 출력하세요.

# %%
try:
    num = int(input("숫자를 입력하세요."))
except ValueError:
    print("숫자를 입력해야 합니다.")
else:
    print(num/2)
# Out:
# 2.0
