# %%
print(123)
# Out:
# 123

# %%
num = "1"
print(num)
# Out:
# 1

# %%
team_name = "ohgiraffers"
my_team = team_name

team_name = "giraffers_united"

print("team_name", team_name)
print("my_team", my_team)
# Out:
# team_name giraffers_united
# my_team ohgiraffers

# %%
x = 6
y = x
x = 10

print(x)
print(y)
# Out:
# 10
# 6

# %%
team_name = "Friends"
print(team_name)

name_team = "Friends fighting!"
print(name_team)

# 카멜케이스 : teamName(자바와 자바스크립트)
# Out:
# Friends
# Friends fighting!

# %%
우리팀 = "skn 23기"
print(우리팀)
# Out:
# skn 23기

# %%
team_1_name = "skn 23기"
team_1_name
# Out:
# 'skn 23기'

# %%
1_team_name = "skn 23기"
# Out:
#   Cell In[6], line 1
#     1_team_name = "skn 23기"
#      ^
# SyntaxError: invalid decimal literal

# %%
20240101 = "skn-23"
# Out:
#   Cell In[7], line 1
#     20240101 = "skn-23"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
team_@_name = "오지라퍼스"
# Out:
#   Cell In[8], line 1
#     team_@_name = "오지라퍼스"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
else = "오지라퍼스"
# Out:
#   Cell In[10], line 1
#     else = "오지라퍼스"
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 변수의 이름으로써 사용 불가능한 것들 확인

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
10
# Out:
# 10

# %%
print(_)
print(_* 3)
# Out:
# 10
# 30

# %%
x, _, z = (1, 2, 3)
print(x)
print(z)
# Out:
# 1
# 3

# %%
x, *_, y = (1, 2, 3, 4, 5)
print(x)
print(y)
# Out:
# 1
# 5

# %%
for _ in range(3):
    print("hello")
# Out:
# hello
# hello
# hello

# %%
_internal_name = 'one_module'
_internal_version = "1.0"

# %%
million = 1_000_000
print(million)
# Out:
# 1000000

# %%
for_ = 'for blah'
print(for_)
# Out:
# for blah

# %% [markdown]
# _ : 내부용(private) 또는 값 무시
# __ : 이름 숨김
# _xx_ : 매직 메서드(파이썬에서 자동으로 호출)

# %% [markdown]
# 다음 문자열에서 모든 날짜 형식을 바꿔보세요.
#
# text = "오늘은 2025-11-25이고, 내일은 2025-11-26입니다."
#
#
# 목표: "-"를 "/"로 바꿔서
#
# 오늘은 2025/11/25이고, 내일은 2025/11/26입니다.
#
#
# 와 같이 출력되게 만드세요.
#
# replace() 메소드를 사용하세요.

# %%
team_name = "닌자"
print(team_name)    # 닌자

Team_name = "파워레인져"
print(team_name)    # 닌자
print(Team_name)    # Ninja

# %%
우리팀 = "닌자"

# %%
10

# %%
print(_)        # 10
print(_ * 3)    # 30``

# %% [markdown]
# 변수 이름은 스네이크 케이스를 따릅니다. (스네이크 케이스(소문자+언더바))
# first_name에 당신의 이름의 첫 글자를 문자열로 저장하세요.
# last_name에 당신의 성을 문자열로 저장하세요.
# full_name 변수에 first_name과 last_name을 이어붙여서 저장하세요.
# print()를 사용해 full_name을 출력해보세요.

# %%
first_name = "gil-dong"
last_name = "hong"
full_name = first_name + last_name

print(last_name, first_name)
# Out:
# hong gil-dong

# %%
num1 = 1
num2 = 1

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
# Out:
# 2
# 0
# 1
# 1.0

# %%
fruits = ['orange', 'apple','pear','banana','kiwi', 'apple']

print(fruits)
print(fruits[0])

# %%
from collections import deque

dq = deque()

dq.append("a")
dq.append("b")
dq.append("c")

print(dq)    # deque(['a', 'b', 'c'])
