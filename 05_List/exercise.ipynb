# %% [markdown]
# 리스트는 대괄호다!

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple'] 

(fruits)
# Out:
# ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple']

# %%
fruits[1]
# Out:
# 'apple'

# %%
rainbow_split = '빨-주-노-초-파-남-보'

print(rainbow_split.split('-'))
# Out:
# ['빨', '주', '노', '초', '파', '남', '보']

# %%
list1 = []
list2 = list()

print(list1 == list2)
print(type(list1))
print(type(list2))
# Out:
# True
# <class 'list'>
# <class 'list'>

# %%
list3 = list('hello')
print(list3)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
safari_list = ["Bear", "Koara", "Gorilla", "Squirrel"]
another_safari_list = ["Monkey", "Tiger", "Wolf"]

print(safari_list + another_safari_list)
# Out:
# ['Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf']

# %%
safari_list = ["Bear", "Koara", "Gorilla", "Squirrel"]

print(safari_list * 4)    # ['Bear', 'Koara', 'Gorilla', 'Squirrel', 'Bear', 'Koara', 'Gorilla', 'Squirrel', 'Bear', 'Koara', 'Gorilla', 'Squirrel', 'Bear', 'Koara', 'Gorilla', 'Squirrel']
# Out:
# ['Bear', 'Koara', 'Gorilla', 'Squirrel', 'Bear', 'Koara', 'Gorilla', 'Squirrel', 'Bear', 'Koara', 'Gorilla', 'Squirrel', 'Bear', 'Koara', 'Gorilla', 'Squirrel']

# %%
fruits = ['orange', 'apple','pear','banana','kiwi', 'apple']

# %%
print("apple:", fruits.count('apple'))
# Out:
# apple: 2

# %%
print("test:", fruits.count("test"))
# Out:
# test: 0

# %%
print("index:", fruits.index("apple"))
# Out:
# index: 1

# %%
print("index:", fruits.index("apple", 3))
# Out:
# index: 4

# %%
fruits.reverse()
print(fruits)    # ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange']
# Out:
# ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange']

# %%
fruits.append("pineapple")
print(fruits)    # ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple']
# Out:
# ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple']

# %%
fruits.extend(['rainbow friut', 'sweet lemon', 'happy apple'])
print(fruits)    # ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple', 'rainbow friut', 'sweet lemon', 'happy apple']
# Out:
# ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple', 'rainbow friut', 'sweet lemon', 'happy apple']

# %%
fruits.insert(0, 'monkey banana')
print(fruits)    # ['monkey banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple', 'rainbow friut', 'sweet lemon', 'happy apple']
# Out:
# ['monkey banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple', 'rainbow friut', 'sweet lemon', 'happy apple']

# %%
fruits.sort()
print(fruits)    # ['apple', 'apple', 'banana', 'happy apple', 'kiwi', 'monkey banana', 'orange', 'pear', 'pineapple', 'rainbow friut', 'sweet lemon']
# Out:
# ['apple', 'apple', 'banana', 'happy apple', 'kiwi', 'monkey banana', 'orange', 'pear', 'pineapple', 'rainbow friut', 'sweet lemon']

# %%
# 내림차순 정렬
fruits.sort(reverse=True)
print(fruits)    # ['sweet lemon', 'rainbow friut', 'pineapple', 'pear', 'orange', 'monkey banana', 'kiwi', 'happy apple', 'banana', 'apple', 'apple']
# Out:
# ['sweet lemon', 'rainbow friut', 'pineapple', 'pear', 'orange', 'monkey banana', 'kiwi', 'happy apple', 'banana', 'apple', 'apple']

# %%
# 문자열 길이가 짧은 순으로 정렬

fruits.sort(key=len)
print(fruits)    # ['pear', 'kiwi', 'apple', 'apple', 'orange', 'banana', 'pineapple', 'sweet lemon', 'happy apple', 'rainbow friut', 'monkey banana']
# Out:
# ['pear', 'kiwi', 'apple', 'apple', 'orange', 'banana', 'pineapple', 'sweet lemon', 'happy apple', 'rainbow friut', 'monkey banana']

# %%
fruits.sort(key=lambda x:(len(x), x))
print(fruits)
# Out:
# ['kiwi', 'pear', 'apple', 'apple', 'banana', 'orange', 'pineapple', 'happy apple', 'sweet lemon', 'monkey banana', 'rainbow friut']

# %%
temp = fruits.remove('kiwi')
print(temp)
print(fruits)
# Out:
# None
# ['pear', 'apple', 'apple', 'banana', 'orange', 'pineapple', 'happy apple', 'sweet lemon', 'monkey banana', 'rainbow friut']

# %%
lst = [2, 3, 5, 1, 4]
lst2 = sorted(lst)

print(lst)
print(lst2)
# Out:
# [2, 3, 5, 1, 4]
# [1, 2, 3, 4, 5]

# %%
temp = fruits.pop()
print(temp)
print(fruits)
# Out:
# rainbow friut
# ['pear', 'apple', 'apple', 'banana', 'orange', 'pineapple', 'happy apple', 'sweet lemon', 'monkey banana']

# %%
plates = ['plate1', 'plate2']

plates.append('plate3')
plates.append('plate4')

print(plates)
# Out:
# ['plate1', 'plate2', 'plate3', 'plate4']

# %%
print(plates.pop())
print(plates)
print(plates.pop())
print(plates.pop())
print(plates)
# Out:
# plate4
# ['plate1', 'plate2', 'plate3']
# plate3
# plate2
# ['plate1']

# %%
abclist = ['A', 'B', 'C', 'D', 'E', 'F']
print(abclist)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
del abclist[0]
print(abclist)
# Out:
# ['B', 'C', 'D', 'E', 'F']

# %%
del abclist[1:3] #[시작:끝-1] 중요
print(abclist)
# Out:
# ['B', 'E', 'F']

# %%
del abclist[:] #시작 전부터 끝까지
print(abclist)
# Out:
# []

# %%
del abclist
print(abclist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 del abclist
# ----> 2 print(abclist)
#
# NameError: name 'abclist' is not defined

# %%
from collections import deque

dq = deque()

dq.append("a")
dq.append("b")
dq.append("c")

print(dq)
# Out:
# deque(['a', 'b', 'c'])

# %%
dq.appendleft('x')
print(dq)
# Out:
# deque(['x', 'a', 'b', 'c'])

# %%
value = dq.pop()
print(value)

left_value = dq.popleft()
print(left_value)

print(dq)
# Out:
# b
# a
# deque([])

# %%
tuples = (1, 2, 'hello')
print(tuples)
print(tuples[0])
print(tuples[1])
print(tuples[2])
# Out:
# (1, 2, 'hello')
# 1
# 2
# hello

# %%
tuples = (1, 2, 'hello'), ('test', 1, 2, 3, 4)
print(tuples)
print(tuples[0])
print(tuples[1][0])
# Out:
# ((1, 2, 'hello'), ('test', 1, 2, 3, 4))
# (1, 2, 'hello')
# test

# %%
no_wrap_turples = 1, 2, 3
print(no_wrap_turples)
# Out:
# (1, 2, 3)

# %%
testlist = (1,2,3,4,)
print(id(testlist))

testlist = (3, 4, 5)
print(id(testlist))
# Out:
# 2687889758928
# 2687888886256

# %%
safari_tuple = ('Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf')
another_safari_tuple = ("Monkey", "Tiger", "Wolf")


print(safari_tuple+another_safari_tuple)
# Out:
# ('Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf', 'Monkey', 'Tiger', 'Wolf')

# %%
print(safari_tuple * 3)
# Out:
# ('Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf', 'Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf', 'Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf')

# %%
print(len(another_safari_tuple+safari_tuple))
# Out:
# 10

# %%
x, y, z = 1,2,3
print(x,y,z)
print(type(x))
# Out:
# 1 2 3
# <class 'int'>

# %%
x,y = y,x
print(x, y)
# Out:
# 2 1

# %%
x,y,z = y,z,x
print(x, y, z)
# Out:
# 1 3 2

# %%
name = "ohgiraffers"
print(type(name))
# Out:
# <class 'str'>

# %%
address = "대한민국 서울시 서초구"
print(address[5]) # 
print(address[9]) #
# Out:
# 서
# 서

# %%
location = ['서울특별시', '부산광역시', '인천광역시', '광주광역시', '울산광역시']
print(location[3])    # 인천광역시
# Out:
# 광주광역시

# %%
address = '대한민국 서울시 서초구'
print(address[-3])    #음수는 뒤에서 1부터 시작한다.
print(address[-7])
# Out:
# 서
# 서

# %%
location = ['서울특별시', '부산광역시', '인천광역시', '광주광역시', '울산광역시']
print(location[-5])
# Out:
# 서울특별시

# %%
address = '대한민국 서울시 서초구'
print(address[5:8])
# Out:
# 서울시

# %%
location = ['서울', '부산', '인천', '광주', '울산']
print(location[2:5])
print(location[2:])
# Out:
# ['인천', '광주', '울산']
# ['인천', '광주', '울산']

# %%
address = '대한민국 서울시 서초구'
print(address[9:])
print(address[-3:])
print(address[1:12:4])
print(address[::-1])
# Out:
# 서초구
# 서초구
# 한서서
# 구초서 시울서 국민한대

# %%
location = ['서울', '부산', '인천', '광주', '울산']
print(location[3:])
print(location[-4:])
print(location[1:4:2])
print(location[2::-1])
# Out:
# ['광주', '울산']
# ['부산', '인천', '광주', '울산']
# ['부산', '광주']
# ['인천', '부산', '서울']

# %%
nation = ('대한민국', '미국', '중국', '일본', '프랑스','대한민국', '미국', '중국', '일본', '프랑스')
print(nation[1:]) #미국 ~ 끝
print(nation[-3:]) #, 중국 ~ 끝
print(nation[2::-1]) # 미국, 일본

print(nation[6::-2]) 
print(nation[::-1]) # 프랑스 ~ 대한민국
# Out:
# ('미국', '중국', '일본', '프랑스', '대한민국', '미국', '중국', '일본', '프랑스')
# ('중국', '일본', '프랑스')
# ('중국', '미국', '대한민국')
# ('미국', '프랑스', '중국', '대한민국')
# ('프랑스', '일본', '중국', '미국', '대한민국', '프랑스', '일본', '중국', '미국', '대한민국')

# %%
address = '대한민국 서울시 서초구'
print('대한민국' in address)       # True
print('국민한대' in address)       # False
print('서울시서초구' in address)    # False
# Out:
# True
# False
# False

# %%
location = ['서울특별시', '부산광역시', '인천광역시', '광주광역시', '울산광역시']
print('광주광역시' in location)                   # True
print(['광주광역시', '부산광역시'] in location)    # False
print(['서울특별시', '부산광역시'] in location)    # False
# Out:
# True
# False
# False

# %%
nation = ('대한민국', '미국', '중국', '일본', '프랑스',('대한민국', '미국'))
print('미국' in nation)                 # True
print(('대한민국', '미국') in nation)    # False
# Out:
# True
# True

# %%
print(nation[1])
print(nation[5][1])
# Out:
# 미국
# 미국

# %%
address = '대한민국 서울시 서초구'
print(len(address)) #12

# %%
location = ['서울', '부산', '인천', '광주', '울산']
print(len(address)) #5

# %%
nation = ('대한민국', '미국', '중국', '일본', '프랑스',('대한민국', '미국'))
print(len(address)) #6

# %% [markdown]
# 아래 조건에 맞게 리스트를 선언하고 결과를 출력하세요.
#
# 1. `fruits`라는 리스트에 다음 요소를 저장하세요.
#     `'apple', 'banana', 'cherry'`.
# 2. `print()`를 사용해 `fruits`의 첫 번째 요소와 세 번째 요소를 출력하세요.

# %%
fruits = ['apple', 'banana', 'cherry']
print(fruits[0])
print(fruits[2])
# Out:
# apple
# cherry

# %% [markdown]
# 다음 조건을 만족하는 리스트를 만드세요.
#
# 1. `numbers`라는 리스트를 선언하고 숫자 `1`부터 `5`까지 저장하세요.
# 2. 이 리스트의 **길이**를 출력하세요.

# %%
numbers = ['1', '2', '3', '4', '5']
print(len(numbers))
# Out:
# 5

# %% [markdown]
# 다음 조건에 맞게 리스트를 조작하세요.
#
# 1. `animals` 리스트에 `'cat', 'dog', 'bird'`를 저장하세요.
# 2. 이 리스트의 마지막에 `'fish'`를 추가하고, 리스트를 출력하세요.

# %%
animals = ['cat', 'dog', 'bird']
animals.append("fish")
print(animals)
# Out:
# ['cat', 'dog', 'bird', 'fish']

# %% [markdown]
# 아래 조건에 맞는 프로그램을 작성하세요.
#
# 1. `numbers` 리스트에 숫자 `3, 6, 9`를 저장하세요.
# 2. 리스트의 첫 번째 요소를 **2배**로 만들어 다시 저장하고, 리스트를 출력하세요.

# %%
numbers = [3, 6, 9]

# %%
numbers[0] = numbers[0]*2
print(numbers)
# Out:
# [6, 6, 9]

# %% [markdown]
# 아래 문자열을 리스트로 변환하고 결과를 출력하세요.
#
# 1. 문자열 `'Python-is-fun'`을 `'-'`를 기준으로 분리하여 리스트로 만드세요.
# 2. 결과 리스트를 출력하세요.

# %%
rainbow_split = 'Python-is-fun'.split("-")
print(rainbow_split)
# Out:
# ['Python', 'is', 'fun']

# %% [markdown]
# 다음 조건에 맞게 튜플을 선언하고 활용하세요.
# 1. `my_tuple`이라는 이름으로 숫자 `10, 20, 30`을 가진 튜플을 선언하세요.
# 2. `my_tuple`의 두 번째 요소를 출력하세요.

# %%
my_tuple = 10, 20, 30
print(type(my_tuple))
print(my_tuple[1])
# Out:
# <class 'tuple'>
# 20

# %% [markdown]
# ### **문제 7**
#
# 아래 조건에 맞게 리스트의 요소를 수정하세요.
#
# 1. `colors` 리스트에 `'red', 'blue', 'green'`을 저장하세요.
# 2. `'blue'`를 `'yellow'`로 변경하고 리스트를 출력하세요.

# %%
colors = ['red', 'blue', 'green']
colors[1] = 'yellow'
print(colors)
# Out:
# ['red', 'yellow', 'green']

# %% [markdown]
# 1. 리스트 `numbers`에 숫자 `1, 2, 3, 4, 5`를 저장하세요.
# 2. 슬라이싱을 이용하여 다음을 수행하세요:
#     - 리스트의 **처음 3개의 요소**를 출력하세요.
#     - 리스트의 **마지막 2개의 요소**를 출력하세요.
#     - 리스트의 **모든 요소를 역순**으로 출력하세요.

# %%
numbers = [1, 2, 3, 4, 5]
print(numbers[0:3])
print(numbers[3:5])
print(numbers[::-1])
# Out:
# [1, 2, 3]
# [4, 5]
# [5, 4, 3, 2, 1]

# %%
words = ['life', 'is', 'too', 'short']

result = ' '.join(words)

print(result)
# Out:
# life is too short
